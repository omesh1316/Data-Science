# %% [markdown]
# # Quiz on List

# %% [markdown]
# ### Create a list a_list, with the following elements 1, hello, [1,2,3] and True.

# %%
# Write your code below and press Shift+Enter to execute
a_list=[1,'hello',[1,2,3],True]
a_list
# Out:
# [1, 'hello', [1, 2, 3], True]

# %% [markdown]
# ### Find the value stored at index 1 of a_list.

# %%
# Write your code below and press Shift+Enter to execute
print(a_list[1])
# Out:
# hello

# %% [markdown]
# ### Retrieve the elements stored at index 1, 2 and 3 of a_list.

# %%
# Write your code below and press Shift+Enter to execute
a_list[1:4]
# Out:
# ['hello', [1, 2, 3], True]

# %% [markdown]
# ### Concatenate the following lists A = [1, 'a'] and B = [2, 1, 'd']:

# %%
# Write your code below and press Shift+Enter to execute
A = [1,'a']
B = [2,1,'d']

print(A+B)
# Out:
# [1, 'a', 2, 1, 'd']

# %% [markdown]
# # Scenario : Shopping list

# %% [markdown]
# # Task-1 Create an empty list
# ### At first we need to create a empty list for storing the items to buy in Shopping list.

# %%
#Type your code here
shopping_list = []
print("Empty List created :-", shopping_list)
# Out:
# Empty List created :- []

# %% [markdown]
# # Task-2 Now store the number of items to the shopping_list
# - Watch
# - Laptop
# - Shoes
# - Pen
# - Clothes

# %%
#Type your code here
shopping_list = ['Watch','Laptp','Shoes','Pen','Clothes']
print("Iteam Stored Successfully !!")
# Out:
# Iteam Stored Successfully !!

# %% [markdown]
# # Task-3 Add a new item to the shopping_list
# ## Seems like I missed one item "Football" to add in the shopping list.

# %%
#Type your code here
shopping_list.append("Football")
print("Missing Iteam Added...")
# Out:
# Missing Iteam Added...

# %% [markdown]
# # Task-4 Print First item from the shopping_list
# ## Let's check the first item that we need to buy.

# %%
#Type your code here
print("The First Iteam IS :-",shopping_list[0])
# Out:
# The First Iteam IS :- Watch

# %% [markdown]
# # Task-5 Print Last item from the shopping_list
# Let's check the last time that we need to buy.

# %%
#Type your code here
print("The Last Iteam Is :-",shopping_list[-1])
# Out:
# The Last Iteam Is :- Football

# %% [markdown]
# # Task-6 Print the entire Shopping List

# %%
#Type your code here.
print(shopping_list)
# Out:
# ['Watch', 'Laptp', 'Shoes', 'Pen', 'Clothes', 'Football', 'Football']

# %% [markdown]
# # Task-7 Print the item that are important to buy from the Shopping List
# Print "Laptop" and "shoes"

# %%
#Type your code here
print(shopping_list[1:3])
# Out:
# ['Laptp', 'Shoes']

# %% [markdown]
# # Task-8 Change the item from the shopping_list
# Instead of <u>"Pen"</u> I want to buy <u>"Notebook"</u>
# let's change the item stored in the list.
# <br>

# %%
#Type your code here
shopping_list[3] = "Notebook"
print("Iteam Changed")
# Out:
# Iteam Changed

# %% [markdown]
# # Task-9 Delete the item from the shopping_list that is not required
# Let's delete items that are unimportant, such as; I don't want to buy <u>Clothes</u>, let's delete it.
# <br>

# %%
#Type your code here
del shopping_list[4]
print("Iteam Deleted...")
# Out:
# Iteam Deleted...

# %% [markdown]
# # Task-10 Print the shopping list
# We are ready with our shopping list.

# %%
# Type your code here
print(shopping_list)
# Out:
# ['Watch', 'Laptp', 'Shoes', 'Notebook', 'Football']
